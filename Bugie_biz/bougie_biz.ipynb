# %%
#import
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import nltk
from nltk.corpus import stopwords
import string
#You will have to download the set of stop words the first time
#nltk.download('stopwords')
#nltk.download('punkt')
from collections import Counter

# %%
#define
top_N = 10000
stopwords = nltk.corpus.stopwords.words('english')
#we need to rename this directory to wherever the CSV files are located
yelp_attr = pd.read_csv('yelp_business_attributes.csv')
yelp_rev = pd.read_csv('yelp_review.csv',nrows = 10000)
bougie_businesses = pd.read_csv('Bougie_Businesses.csv')
yelp_business_data = pd.read_csv('yelp_business.csv')

# %%
yelp_business_data.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# 1  40.291685  -80.104900    3.0            11        1
# 2  33.524903 -112.115310    1.5            18        1
# 3  33.383147 -111.964725    3.0             9        0
# 4  41.119535  -81.475690    3.5           116        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
#Combine Ambience and Reviews into a Dataframe
yelp_reviewd = pd.merge(yelp_rev, yelp_attr, on='business_id')
i = 0
for index, row in yelp_reviewd.iterrows():    
    yelp_reviewd.loc[index, "is_bougie"] = row["stars"] == 5
yelp_reviewd.head(10)
#list(yelp_reviewd.columns.values)
# Out:
#                 review_id                 user_id             business_id  \
# 0  vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA
# 1  vm1b1keOzwHjtGZEPPuYXA  xYciRtVZ1PW4IxSX4oJ1aw  AEx2SYEUJmTxVVB18LlCwA
# 2  n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w
# 3  MV3CcKScW05u5LVfF6ok0g  bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g
# 4  IXvOzsEMYtiJI0CARmj77Q  bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA
# 5  i5kyjrSfzAC-RJLTYx6pTQ  pnASSACWj87icFTteMkbtA  ACFtxLv8pGrrxMm6EgjreA
# 6  L_9BTb55X0GDtThi6GlZ6w  bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q
# 7  HRPm3vEZ_F-33TYVT7Pebw  _4iMDXbXZ1p1ONG297YEAQ  8QWPlVQ6D-OExqXoaD2Z1g
# 8  ymAUG8DZfQcFTBSOiaNN4w  u0LXt3Uea_GidxRW1xcsfg  9_CGhHMz8698M9-PkVf0CQ
# 9  8UIishPUD92hXtScSga_gw  u0LXt3Uea_GidxRW1xcsfg  gkCorLgPyQLsptTHalL61g
#
#    stars        date                                               text  \
# 0      5  2016-05-28  Super simple place but amazing nonetheless. It...
# 1      5  2016-02-22  *The shop was featured on Mind of a Chef with ...
# 2      5  2016-05-28  Small unassuming place that changes their menu...
# 3      5  2016-05-28  Lester's is located in a beautiful neighborhoo...
# 4      4  2016-05-28  Love coming here. Yes the place always needs t...
# 5      5  2014-06-28  Wow, just the most tasty burguer I've ever had...
# 6      4  2016-05-28  Had their chocolate almond croissant and it wa...
# 7      5  2014-09-24  Cycle Pub Las Vegas was a blast! Got a groupon...
# 8      4  2012-05-11  Who would have guess that you would be able to...
# 9      4  2015-10-27  Always drove past this coffee house and wonder...
#
#    useful  funny  cool AcceptsInsurance    ...     \
# 0       0      0     0               Na    ...
# 1       4      3     4               Na    ...
# 2       0      0     0               Na    ...
# 3       0      0     0               Na    ...
# 4       0      0     0               Na    ...
# 5       0      0     0               Na    ...
# 6       0      0     0               Na    ...
# 7       1      0     0               Na    ...
# 8       0      0     2               Na    ...
# 9       1      0     0               Na    ...
#
#   DietaryRestrictions_dairy-free DietaryRestrictions_gluten-free  \
# 0                             Na                              Na
# 1                             Na                              Na
# 2                             Na                              Na
# 3                             Na                              Na
# 4                             Na                              Na
# 5                             Na                              Na
# 6                             Na                              Na
# 7                             Na                              Na
# 8                             Na                              Na
# 9                             Na                              Na
#
#   DietaryRestrictions_vegan DietaryRestrictions_kosher  \
# 0                        Na                         Na
# 1                        Na                         Na
# 2                        Na                         Na
# 3                        Na                         Na
# 4                        Na                         Na
# 5                        Na                         Na
# 6                        Na                         Na
# 7                        Na                         Na
# 8                        Na                         Na
# 9                        Na                         Na
#
#   DietaryRestrictions_halal DietaryRestrictions_soy-free  \
# 0                        Na                           Na
# 1                        Na                           Na
# 2                        Na                           Na
# 3                        Na                           Na
# 4                        Na                           Na
# 5                        Na                           Na
# 6                        Na                           Na
# 7                        Na                           Na
# 8                        Na                           Na
# 9                        Na                           Na
#
#   DietaryRestrictions_vegetarian AgesAllowed RestaurantsCounterService  \
# 0                             Na          Na                        Na
# 1                             Na          Na                        Na
# 2                             Na          Na                        Na
# 3                             Na          Na                        Na
# 4                             Na          Na                        Na
# 5                             Na          Na                        Na
# 6                             Na          Na                        Na
# 7                             Na          Na                        Na
# 8                             Na          Na                        Na
# 9                             Na          Na                        Na
#
#   is_bougie
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
#
# [10 rows x 91 columns]

# %%
#With the New Bugie Businesses
bougie_biz = pd.merge( bougie_businesses, yelp_business_data, on='business_id', how='left')
bougie_biz.head(-10)
# Out:
#                  business_id  Bougie_Rating  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0     El4FC8jcawUVgw_0EIcbaQ            133         NaN                   NaN
# 1     g8OnV26ywJlZpezdBnOWUQ            129         NaN        NaN        NaN
# 2     JmI9nslLD7KZqRr__Bg6NQ            127         NaN        NaN        NaN
# 3     Wxxvi3LZbHNIDwJ-ZimtnA            126         NaN        NaN        NaN
# 4     XZbuPXdyA0ZtTu3AzqtQhg            120         NaN        NaN        NaN
# 5     q3dJQtwZQrrurNT-1bNKgQ            116         NaN        NaN        NaN
# 6     UBQRhqRMW4Sk7kSZvZ1iAQ            105         NaN        NaN        NaN
# 7     k1QpHAkzKTrFYfk6u--VgQ            103         NaN        NaN        NaN
# 8     ALn_0f-Usn3n0a9WBcjhhg            102         NaN        NaN        NaN
# 9     mPfdYJj4d5KBPINDkaZY-Q            102         NaN        NaN
# 10    QYIhMNwxXejDoCr-F1BxDg             96         NaN        NaN        NaN
# 11    Az_60nNuh1FH8Ds8oasZjw             95         NaN        NaN        NaN
# 12    yfxDa8RFOvJPQh0rNtakHA             93         NaN        NaN        NaN
# 13    Hr5h_LG9TMBLlFz_Oici0A             93         NaN        NaN        NaN
# 14    eAc9Vd6loOgRQolMXQt6FA             92         NaN        NaN        NaN
# 15    6tLL1P8k9drb7MJEVwmRhg             92         NaN        NaN        NaN
# 16    _w5hBpkjHs5_Hv3pLeHtIw             91         NaN        NaN        NaN
# 17    PVTfzxu7of57zo1jZwEzkg             89         NaN        NaN        NaN
# 18    zgQHtqX0gqMw1nlBZl2VnQ             88         NaN        NaN        NaN
# 19    na4Th5DrNauOv-c43QQFvA             86         NaN        NaN        NaN
# 20    qjnJFZtsY_nfRzoL3J_UWQ             85         NaN        NaN        NaN
# 21    XMMLRvV4IMxIGyc4H37LxA             84         NaN        NaN        NaN
# 22    hRL_qCrcu9UL773su0QabQ             84         NaN        NaN        NaN
# 23    5FIOXmUE3qMviX9GafGH-Q             84         NaN        NaN        NaN
# 24    fSFzgt_QzJRUN0qNzTAwig             83         NaN        NaN        NaN
# 25    moZpwq1hNxC-uJRpfupOTA             81         NaN        NaN        NaN
# 26    rcaPajgKOJC2vo_l3xa42A             81         NaN        NaN        NaN
# 27    ZHQU79PMUGCX0fEoyCcWlw             79         NaN        NaN        NaN
# 28    XXW_OFaYQkkGOGniujZFHg             78         NaN        NaN        NaN
# 29    AfN3Z1U6QPEgAb5F2CQm8w             78         NaN        NaN        NaN
# ...                      ...            ...         ...        ...        ...
# 1059  iihSyIgl_1Kz7QU5s0R7bQ              4         NaN        NaN        NaN
# 1060  EHDcxAlrrP4VPiZuQlrIrg              4         NaN        NaN        NaN
# 1061  Zrx25j1M794Nh8fUGB8E9A              4         NaN        NaN        NaN
# 1062  gsjxrwdHqKdTeNx3GeDKNQ              4         NaN        NaN        NaN
# 1063  ZAuAwz1ijuydn5yL3q3rzA              4         NaN        NaN        NaN
# 1064  aZLggARpUrEpdalQqPUI0Q              4         NaN        NaN        NaN
# 1065  ByLGceeU4oxmwUDxexYrQw              3         NaN        NaN        NaN
# 1066  J0KZR0DDnvj73D-xmbh4uA              3         NaN        NaN        NaN
# 1067  So132GP_uy3XbGs0KNyzyw              3         NaN        NaN        NaN
# 1068  0QzCeORfF8EY34UODWRV9A              3         NaN        NaN        NaN
# 1069  60uVlCUiLJvq3xNo_3bhQQ              3         NaN        NaN        NaN
# 1070  xObQl57iTZrg8-hfMkMF6g              3         NaN        NaN        NaN
# 1071  QC9bLPcNk6ymAOHf03pHhQ              3         NaN        NaN        NaN
# 1072  Vq-peJrXYkVWPPngMQi0Lg              3         NaN        NaN        NaN
# 1073  CaVbq701PdDX9F8oqQTfmQ              3         NaN        NaN        NaN
# 1074  poOnGeQlHEnWRAH9t_0KMg              3         NaN        NaN        NaN
# 1075  q-YQIvBSNZxYJl1xuB0H_w              3         NaN        NaN        NaN
# 1076  RRWJ1l8YDNYKh8LV7QRabw              3         NaN        NaN        NaN
# 1077  YQ--LJ7pvjiDSqNv0TuKTQ              3         NaN        NaN        NaN
# 1078  vcxvQyAggPqxcHwvJXvjGg              2         NaN        NaN        NaN
# 1079  qR62k9TVEVwRuQH6-4avHA              2         NaN        NaN        NaN
# 1080  vtJKOOyg0NisrB45K33cdQ              2         NaN        NaN        NaN
# 1081  1Lbq92b6B9z1FYk5mS2R9Q              2         NaN        NaN        NaN
# 1082  M5dqqrla2JsBn5G3pV3Dmg              2         NaN        NaN        NaN
# 1083  cZBCVzd4lg_jx8IiFz-Iag              2         NaN        NaN        NaN
# 1084  K8MWIwCrS5w-Dbi9UHOlhw              2         NaN        NaN        NaN
# 1085  48OQw36mJ_xhOvR7duH1kg              2         NaN        NaN        NaN
# 1086  XgsIf7s2zM-cC29WUD-NZQ              2         NaN        NaN        NaN
# 1087  WyZAeMGsjUE7OToI4Jdqfw              2         NaN        NaN        NaN
# 1088  WFB1fn8rWNukmmIfTg6AMw              2         NaN        NaN        NaN
#
#                                                    name        neighborhood  \
# 0                                     "MGM Grand Hotel"           The Strip
# 1                                  "Hash House A Go Go"            Westside
# 2            "Phoenix Sky Harbor International Airport"                 NaN
# 3                              "The Venetian Las Vegas"           The Strip
# 4                                          "Mesa Grill"           The Strip
# 5                              "Capo's Italian Cuisine"            Westside
# 6                                 "Essence Bakery Café"                 NaN
# 7                                          "The Parlor"                 NaN
# 8                                             "Hanny's"                 NaN
# 9                                               "Churn"                 NaN
# 10                                         "Thai Basil"                 NaN
# 11                                             "Encore"           The Strip
# 12                                       "Pho Kim Long"           Chinatown
# 13                                          "Caffe Boa"                 NaN
# 14                       "Mandalay Bay Resort & Casino"           The Strip
# 15                                     "Papago Brewing"                 NaN
# 16                               "Julian Serrano Tapas"           The Strip
# 17                                                "FEZ"                 NaN
# 18                                "Momofuku Noodle Bar"  Financial District
# 19                                     "Bellagio Hotel"           The Strip
# 20                   "New York New York Hotel & Casino"           The Strip
# 21                                  "True Food Kitchen"                 NaN
# 22                         "Kabuki Japanese Restaurant"                 NaN
# 23                      "Green New American Vegetarian"                 NaN
# 24                                      "The Roosevelt"                 NaN
# 25                                    "Carlsbad Tavern"                 NaN
# 26                       "Bouchon at the Venezia Tower"           The Strip
# 27                                    "Caribbean Spice"                 NaN
# 28        "The Peppermill Restaurant & Fireside Lounge"           The Strip
# 29                         "Casey Moore's Oyster House"                 NaN
# ...                                                 ...                 ...
# 1059  "La Quinta Inn & Suites Las Vegas Airport N Co...            Eastside
# 1060                          "Cabo Mexican Restaurant"           Northwest
# 1061                                      "TGI Fridays"                 NaN
# 1062                                        "McDonalds"                 NaN
# 1063                               "Japanese Curry Zen"           Chinatown
# 1064           "Ghirardelli Ice Cream & Chocolate Shop"           The Strip
# 1065                                         "VIKA SPA"           The Annex
# 1066                                         "Autozone"           Southwest
# 1067                                    "Casa Di Amore"            Eastside
# 1068                    "Sunset Station Hotel & Casino"                 NaN
# 1069                          "Carmine's Pizza Kitchen"       Spring Valley
# 1070                                   "Ice Box Canyon"                 NaN
# 1071                                         "Del Taco"       Spring Valley
# 1072                                    "Outpost Motel"                 NaN
# 1073                                       "Albertsons"           The Lakes
# 1074                                       "NYPD Pizza"                 NaN
# 1075                          "CM2 Pizzeria & Bakeshop"                 NaN
# 1076                                "Lone Butte Casino"                 NaN
# 1077                              "Grimaldi's Pizzeria"           The Strip
# 1078                                 "Bobbette & Belle"         Leslieville
# 1079                                "Loews Hotel Vogue"         Ville-Marie
# 1080                              "Holiday Inn Express"                 NaN
# 1081                          "Big Dog's Cafe & Casino"            Westside
# 1082                                    "Bonanza Trail"                 NaN
# 1083                                        "Carl's Jr"            Westside
# 1084                 "Sam's Town Hotel & Gambling Hall"                 NaN
# 1085                                  "Foothills Ranch"           Northwest
# 1086                    "Makino Sushi & Seafood Buffet"                 NaN
# 1087                           "Chipotle Mexican Grill"            Westside
# 1088                                   "Ay Caramba, Eh"                 NaN
#
#                                                 address        city state  \
# 0                               "3799 Las Vegas Blvd S"   Las Vegas    NV
# 1                                   "6800 W Sahara Ave"   Las Vegas    NV
# 2                    "3400 E Sky Harbor Blvd, Ste 3300"     Phoenix    AZ
# 3                      "3355 South Las Vegas Boulevard"   Las Vegas    NV
# 4                               "3570 Las Vegas Blvd S"   Las Vegas    NV
# 5                                   "5675 W Sahara Ave"   Las Vegas    NV
# 6                                 "825 W University Dr"       Tempe    AZ
# 7                                 "1916 E Camelback Rd"     Phoenix    AZ
# 8                                         "40 N 1st St"     Phoenix    AZ
# 9                                  "5223 N Central Ave"     Phoenix    AZ
# 10                                "403 W University Dr"       Tempe    AZ
# 11                              "3131 Las Vegas Blvd S"   Las Vegas    NV
# 12                            "4029 Spring Mountain Rd"   Las Vegas    NV
# 1084       89122  36.112835 -115.062444    3.5           465        1
# 1085       89130  36.219935 -115.215492    3.5             5        0
# 1086       89103  36.118632 -115.208459    3.5           560        1
# 1087       89117  36.144779 -115.297331    3.5           131        1
# 1088     L4H 3T8  43.828544  -79.549093    4.5           137        1
#
#                                              categories
# 0     Restaurants;Arts & Entertainment;Hotels;Event ...
# 1         Restaurants;Breakfast & Brunch;American (New)
# 2                              Hotels & Travel;Airports
# 3     Casinos;Hotels;Resorts;Arts & Entertainment;Ev...
# 4     New Mexican Cuisine;Mexican;Restaurants;Southe...
# 5                                   Restaurants;Italian
# 6            Restaurants;Cafes;Bakeries;Food;Sandwiches
# 7            Sandwiches;Salad;Italian;Pizza;Restaurants
# 8     Restaurants;Pizza;Cocktail Bars;Nightlife;Loun...
# 9     Food;Ice Cream & Frozen Yogurt;Desserts;Coffee...
# 10                        Thai;Restaurants;Soup;Noodles
# 11    Resorts;Home & Garden;Casinos;Arts & Entertain...
# 12                       Vietnamese;Chinese;Restaurants
# 13    Restaurants;American (New);Italian;Breakfast &...
# 14    Casinos;Hotels;Hotels & Travel;Resorts;Arts & ...
# 15    Breweries;Food;Restaurants;Pizza;Sandwiches;Wraps
# 16                       Spanish;Tapas Bars;Restaurants
# 17    Restaurants;Bars;Nightlife;Mediterranean;Loung...
# 18    American (New);Ramen;Asian Fusion;Restaurants;...
# 19    Hotels;Arts & Entertainment;Hotels & Travel;Ev...
# 20    Hotels;Resorts;Casinos;Event Planning & Servic...
# 21    Restaurants;Salad;American (New);Vegetarian;Vegan
# 22         Asian Fusion;Japanese;Restaurants;Sushi Bars
# 23             Vegan;Vegetarian;Gluten-Free;Restaurants
# 24            Bars;American (New);Nightlife;Restaurants
# 25    Breakfast & Brunch;Restaurants;Nightlife;Bars;...
# 26    Breakfast & Brunch;Venues & Event Spaces;Event...
# 27                                Restaurants;Caribbean
# 28    Bars;American (Traditional);Lounges;Nightlife;...
# 29        Restaurants;Irish;Bars;Pubs;Seafood;Nightlife
# ...                                                 ...
# 1059   Hotels;Event Planning & Services;Hotels & Travel
# 1060                                Mexican;Restaurants
# 1061  Bars;Seafood;Nightlife;Restaurants;American (T...
# 1062                      Burgers;Restaurants;Fast Food
# 1063                               Restaurants;Japanese
# 1064  Chocolatiers & Shops;Ice Cream & Frozen Yogurt...
# 1065      Day Spas;Makeup Artists;Beauty & Spas;Massage
# 1066       Auto Parts & Supplies;Auto Repair;Automotive
# 1067  Restaurants;Pizza;Seafood;American (New);Salad...
# 1068  Hotels;Restaurants;Cinema;Hotels & Travel;Arts...
# 1069  Food Delivery Services;Restaurants;Food;Italia...
# 1070                                 Active Life;Hiking
# 1071                                Restaurants;Mexican
# 1072   Hotels;Event Planning & Services;Hotels & Travel
# 1073                   Grocery;Shopping;Food;Drugstores
# 1074                                  Pizza;Restaurants
# 1075  Breakfast & Brunch;Wine Bars;Restaurants;Food;...
# 1076                       Arts & Entertainment;Casinos
# 1077                                  Pizza;Restaurants
# 1078  Caterers;Event Planning & Services;Desserts;Ba...
# 1079   Hotels & Travel;Event Planning & Services;Hotels
# 1080  Hotels;Venues & Event Spaces;Hotels & Travel;E...
# 1081          Nightlife;Bars;Food;Sports Bars;Breweries
# 1082                                 Active Life;Hiking
# 1083                      Burgers;Fast Food;Restaurants
# 1084  Active Life;Bowling;Arts & Entertainment;Hotel...
# 1085                                     Nightlife;Bars
# 1086            Buffets;Sushi Bars;Japanese;Restaurants
# 1087                      Mexican;Fast Food;Restaurants
# 1088                 Latin American;Restaurants;Mexican
#
# [1089 rows x 17 columns]

# %%
bougie_biz.sort_values(by='Bougie_Rating', ascending=True)
# Out:
#                  business_id                                        name  \
# 92    dfRAK2mgdHbL2_YsFqtCdQ                           "Cheyenne Saloon"
# 158   yz2EimDE7bBvq6b4mDe_zg                                      "IHOP"
# 762   V-dxglt0zIcBZzZ-4gfgAw                              "Sunset Nails"
# 1017  CDryASuglHotRaP-8nzYUg       "Sunrise Mountain/Frenchman Mountain"
# 524   kCatAFdvOhpdeV5UZK-7Fw               "Renaissance Las Vegas Hotel"
# 393   sPwgafejYVdf8hd4-oDYVg                                "DD Peckers"
# 333   nMKj8Di_9YTdZcCAWFw3dw                             "Skinny Dugans"
# 361   FUrORC2zXr_keHHlpYjmCA                                   "Chevron"
# 298   WFB1fn8rWNukmmIfTg6AMw                            "Ay Caramba, Eh"
# 987   cZBCVzd4lg_jx8IiFz-Iag                                 "Carl's Jr"
# 519   WyZAeMGsjUE7OToI4Jdqfw                    "Chipotle Mexican Grill"
# 1004  XgsIf7s2zM-cC29WUD-NZQ             "Makino Sushi & Seafood Buffet"
# 395   K8MWIwCrS5w-Dbi9UHOlhw          "Sam's Town Hotel & Gambling Hall"
# 805   1Lbq92b6B9z1FYk5mS2R9Q                   "Big Dog's Cafe & Casino"
# 655   M5dqqrla2JsBn5G3pV3Dmg                             "Bonanza Trail"
# 296   qR62k9TVEVwRuQH6-4avHA                         "Loews Hotel Vogue"
# 293   48OQw36mJ_xhOvR7duH1kg                           "Foothills Ranch"
# 332   vtJKOOyg0NisrB45K33cdQ                       "Holiday Inn Express"
# 9     r_oCBNif2W8mnSXnrXMwPQ                       "Edible Arrangements"
# 325   vcxvQyAggPqxcHwvJXvjGg                          "Bobbette & Belle"
# 533   s6L6SdVYhPcOQEDmNIg1-g                                 "Happy Wok"
# 436   QC9bLPcNk6ymAOHf03pHhQ                                  "Del Taco"
# 501   RRWJ1l8YDNYKh8LV7QRabw                         "Lone Butte Casino"
# 898   0QzCeORfF8EY34UODWRV9A             "Sunset Station Hotel & Casino"
# 55    xObQl57iTZrg8-hfMkMF6g                            "Ice Box Canyon"
# 950   q-YQIvBSNZxYJl1xuB0H_w                   "CM2 Pizzeria & Bakeshop"
# 874   J0KZR0DDnvj73D-xmbh4uA                                  "Autozone"
# 1011  poOnGeQlHEnWRAH9t_0KMg                                "NYPD Pizza"
# 814   So132GP_uy3XbGs0KNyzyw                             "Casa Di Amore"
# 725   Vq-peJrXYkVWPPngMQi0Lg                             "Outpost Motel"
# ...                      ...                                         ...
# 973   Wnq5to0-jXyh0-_jRZ6VOQ                                   "Z Tejas"
# 510   AfN3Z1U6QPEgAb5F2CQm8w                "Casey Moore's Oyster House"
# 130   ZHQU79PMUGCX0fEoyCcWlw                           "Caribbean Spice"
# 339   moZpwq1hNxC-uJRpfupOTA                           "Carlsbad Tavern"
# 32    rcaPajgKOJC2vo_l3xa42A              "Bouchon at the Venezia Tower"
# 300   fSFzgt_QzJRUN0qNzTAwig                             "The Roosevelt"
# 504   XMMLRvV4IMxIGyc4H37LxA                         "True Food Kitchen"
# 609   5FIOXmUE3qMviX9GafGH-Q             "Green New American Vegetarian"
# 1036  hRL_qCrcu9UL773su0QabQ                "Kabuki Japanese Restaurant"
# 99    qjnJFZtsY_nfRzoL3J_UWQ          "New York New York Hotel & Casino"
# 782   na4Th5DrNauOv-c43QQFvA                            "Bellagio Hotel"
# 657   zgQHtqX0gqMw1nlBZl2VnQ                       "Momofuku Noodle Bar"
# 819   PVTfzxu7of57zo1jZwEzkg                                       "FEZ"
# 750   _w5hBpkjHs5_Hv3pLeHtIw                      "Julian Serrano Tapas"
# 206   6tLL1P8k9drb7MJEVwmRhg                            "Papago Brewing"
# 388   eAc9Vd6loOgRQolMXQt6FA              "Mandalay Bay Resort & Casino"
# 917   Hr5h_LG9TMBLlFz_Oici0A                                 "Caffe Boa"
# 1052  yfxDa8RFOvJPQh0rNtakHA                              "Pho Kim Long"
# 551   Az_60nNuh1FH8Ds8oasZjw                                    "Encore"
# 36    QYIhMNwxXejDoCr-F1BxDg                                "Thai Basil"
# 896   mPfdYJj4d5KBPINDkaZY-Q                                     "Churn"
# 959   ALn_0f-Usn3n0a9WBcjhhg                                   "Hanny's"
# 1000  k1QpHAkzKTrFYfk6u--VgQ                                "The Parlor"
# 460   UBQRhqRMW4Sk7kSZvZ1iAQ                       "Essence Bakery Café"
# 759   q3dJQtwZQrrurNT-1bNKgQ                    "Capo's Italian Cuisine"
# 231   XZbuPXdyA0ZtTu3AzqtQhg                                "Mesa Grill"
# 674   Wxxvi3LZbHNIDwJ-ZimtnA                    "The Venetian Las Vegas"
# 18    JmI9nslLD7KZqRr__Bg6NQ  "Phoenix Sky Harbor International Airport"
# 280   g8OnV26ywJlZpezdBnOWUQ                        "Hash House A Go Go"
# 56    El4FC8jcawUVgw_0EIcbaQ                           "MGM Grand Hotel"
#
#             neighborhood                                            address  \
# 92                   NaN                                 "3103 N Rancho Dr"
# 158                  NaN                                 "4860 Boulder Hwy"
# 762                  NaN                      "1801 E Baseline Rd, Ste 103"
# 1017                 NaN                            "6885 E Lake Mead Blvd"
# 524             Eastside                               "3400 Paradise Road"
# 393                  NaN                             "10403 Park Rd, Ste E"
# 333             Westside                           "4127 W Charleston Blvd"
# 361            Northwest                              "4401 N Rainbow Blvd"
# 298                  NaN                          "65-3540 Rutherford Road"
# 987             Westside                                    "9040 W Sahara"
# 519             Westside                       "9240 W Sahara Ave, Ste 150"
# 1004                 NaN                       "3965 S Decatur Blvd, Ste 5"
# 395                  NaN                                 "5111 Boulder Hwy"
# 805             Westside                                "6390 W Sahara Ave"
# 655                  NaN                          "Toiyabe National Forest"
# 296          Ville-Marie                          "1425 Rue De La Montagne"
# 293            Northwest                                 "3377 N Rancho Dr"
# 332                  NaN                                "722 John Nolen Dr"
# 9             Ballantyne                       "12239 N Community House Rd"
# 325          Leslieville                              "1121 Queen Street E"
# 533        Spring Valley                      "5479 S Rainbow Blvd, Ste A1"
# 436        Spring Valley                            "5180 S Fort Apache Rd"
# 501                  NaN                                 "1077 S Kyrene Rd"
# 898                  NaN                                 "1301 W Sunset Rd"
# 55                   NaN                               "3205 State Rte 159"
# 950                  NaN                                 "11485 N 136th St"
# 874            Southwest                              "7490 S Rainbow Blvd"
# 1011                 NaN                          "222 S Mill Ave, Ste 127"
# 814             Eastside                             "2850 E Tropicana Ave"
# 725                  NaN                               "1104 N Boulder Hwy"
# ...                  ...                                                ...
# 973                  NaN                                      "20 W 6th St"
# 510                  NaN                                    "850 S Ash Ave"
# 130                  NaN                      "219 E Baseline St, Ste H001"
# 339                  NaN                                 "3313 N Hayden Rd"
# 32             The Strip  "3355 Las Vegas Blvd S, Venezia Tower, 10th fl...
# 300                  NaN                                     "816 N 3rd St"
# 504                  NaN                              "2502 E Camelback Rd"
# 609                  NaN                             "2240 N Scottsdale Rd"
# 1036                 NaN                    "2000 E Rio Salado Pkwy, #1051"
# 99             The Strip                            "3790 Las Vegas Blvd S"
# 782            The Strip                            "3600 S Las Vegas Blvd"
# 657   Financial District              "190 University Avenue, Ground Floor"
# 819                  NaN                               "3815 N Central Ave"
# 750            The Strip                            "3730 Las Vegas Blvd S"
# 206                  NaN                               "7107 E Mcdowell Rd"
# 388            The Strip                            "3950 S Las Vegas Blvd"
# 917                  NaN                                   "398 S Mill Ave"
# 1052           Chinatown                          "4029 Spring Mountain Rd"
# 551            The Strip                            "3131 Las Vegas Blvd S"
# 36                   NaN                              "403 W University Dr"
# 896                  NaN                               "5223 N Central Ave"
# 959                  NaN                                      "40 N 1st St"
# 1000                 NaN                              "1916 E Camelback Rd"
# 460                  NaN                              "825 W University Dr"
# 759             Westside                                "5675 W Sahara Ave"
# 231            The Strip                            "3570 Las Vegas Blvd S"
# 674            The Strip                   "3355 South Las Vegas Boulevard"
# 18                   NaN                 "3400 E Sky Harbor Blvd, Ste 3300"
# 280             Westside                                "6800 W Sahara Ave"
# 56             The Strip                            "3799 Las Vegas Blvd S"
#
#             city state postal_code   latitude   longitude  stars  \
# 92     Las Vegas    NV       89130  36.215174 -115.212311    3.0
# 158    Las Vegas    NV       89121  36.115529 -115.068487    3.0
# 762        Tempe    AZ       85283  33.377402 -111.908621    4.0
# 1017   Las Vegas    NV       89156  36.202253 -114.989261    4.5
# 524    Las Vegas    NV       89169  36.127239 -115.154416    3.5
# 393    Charlotte    NC       28210  35.093599  -80.867239    4.0
# 1000     Phoenix    AZ       85016  33.509446 -112.040395    4.0
# 460        Tempe    AZ       85281  33.421657 -111.951170    4.0
# 759    Las Vegas    NV       89146  36.143974 -115.219248    4.0
# 231    Las Vegas    NV       89109  36.117125 -115.174793    4.0
# 674    Las Vegas    NV       89109  36.121189 -115.169657    4.0
# 18       Phoenix    AZ       85034  33.435943 -112.011026    3.0
# 280    Las Vegas    NV       89146  36.144667 -115.239955    4.0
# 56     Las Vegas    NV       89109  36.102251 -115.169968    3.0
#
#       review_count  is_open  \
# 92              31        0
# 158             40        1
# 762              9        0
# 1017            37        1
# 524            327        1
# 393            199        1
# 333             38        1
# 361              9        1
# 298            137        1
# 987             28        1
# 519            131        1
# 1004           560        1
# 395            465        1
# 805             67        0
# 655              5        1
# 296             57        1
# 293              5        0
# 332             12        0
# 9                5        1
# 325            140        1
# 533             74        1
# 436             26        1
# 501            117        1
# 898            446        1
# 55              42        1
# 950             41        1
# 874             36        1
# 1011            62        1
# 814            676        1
# 725              3        1
# ...            ...      ...
# 973            276        0
# 510            713        1
# 130            211        1
# 339            726        1
# 32            3570        1
# 300            211        0
# 504           1016        1
# 609           1068        1
# 1036           542        1
# 99            1831        1
# 782           2780        1
# 657            759        1
# 819           1037        0
# 750           1628        1
# 206            452        0
# 388           2687        1
# 917            522        1
# 1052          2594        1
# 551           1726        1
# 36             362        1
# 896            728        1
# 959            709        1
# 1000          1081        1
# 460            439        0
# 759           1089        1
# 231           3012        1
# 674           3101        1
# 18            2215        1
# 280           3050        1
# 56            3444        1
#
#                                              categories  Bougie_Rating  \
# 92    Music Venues;Restaurants;Bars;Dive Bars;Arts &...              1
# 158   Breakfast & Brunch;American (New);Restaurants;...              1
# 762              Nail Salons;Beauty & Spas;Hair Removal              1
# 1017                                 Active Life;Hiking              1
# 524   Hotels & Travel;Venues & Event Spaces;Event Pl...              1
# 393      Restaurants;Burgers;Chicken Wings;Cheesesteaks              1
# 333   Bars;Restaurants;American (New);Pubs;Lounges;D...              1
# 361                             Gas Stations;Automotive              1
# 298                  Latin American;Restaurants;Mexican              2
# 987                       Burgers;Fast Food;Restaurants              2
# 519                       Mexican;Fast Food;Restaurants              2
# 1004            Buffets;Sushi Bars;Japanese;Restaurants              2
# 395   Active Life;Bowling;Arts & Entertainment;Hotel...              2
# 805           Nightlife;Bars;Food;Sports Bars;Breweries              2
# 655                                  Active Life;Hiking              2
# 296    Hotels & Travel;Event Planning & Services;Hotels              2
# 293                                      Nightlife;Bars              2
# 332   Hotels;Venues & Event Spaces;Hotels & Travel;E...              2
# 9     Shopping;Florists;Flowers & Gifts;Candy Stores...              2
# 325   Caterers;Event Planning & Services;Desserts;Ba...              2
# 533                                 Chinese;Restaurants              2
# 436                                 Restaurants;Mexican              3
# 501                        Arts & Entertainment;Casinos              3
# 898   Hotels;Restaurants;Cinema;Hotels & Travel;Arts...              3
# 55                                   Active Life;Hiking              3
# 950   Breakfast & Brunch;Wine Bars;Restaurants;Food;...              3
# 874        Auto Parts & Supplies;Auto Repair;Automotive              3
# 1011                                  Pizza;Restaurants              3
# 814   Restaurants;Pizza;Seafood;American (New);Salad...              3
# 725    Hotels;Event Planning & Services;Hotels & Travel              3
# ...                                                 ...            ...
# 973   American (Traditional);Tex-Mex;Restaurants;Mex...             78
# 510       Restaurants;Irish;Bars;Pubs;Seafood;Nightlife             78
# 130                               Restaurants;Caribbean             79
# 339   Breakfast & Brunch;Restaurants;Nightlife;Bars;...             81
# 32    Breakfast & Brunch;Venues & Event Spaces;Event...             81
# 300           Bars;American (New);Nightlife;Restaurants             83
# 504   Restaurants;Salad;American (New);Vegetarian;Vegan             84
# 609            Vegan;Vegetarian;Gluten-Free;Restaurants             84
# 1036       Asian Fusion;Japanese;Restaurants;Sushi Bars             84
# 99    Hotels;Resorts;Casinos;Event Planning & Servic...             85
# 782   Hotels;Arts & Entertainment;Hotels & Travel;Ev...             86
# 657   American (New);Ramen;Asian Fusion;Restaurants;...             88
# 819   Restaurants;Bars;Nightlife;Mediterranean;Loung...             89
# 750                      Spanish;Tapas Bars;Restaurants             91
# 206   Breweries;Food;Restaurants;Pizza;Sandwiches;Wraps             92
# 388   Casinos;Hotels;Hotels & Travel;Resorts;Arts & ...             92
# 917   Restaurants;American (New);Italian;Breakfast &...             93
# 1052                     Vietnamese;Chinese;Restaurants             93
# 551   Resorts;Home & Garden;Casinos;Arts & Entertain...             95
# 36                        Thai;Restaurants;Soup;Noodles             96
# 896   Food;Ice Cream & Frozen Yogurt;Desserts;Coffee...            102
# 959   Restaurants;Pizza;Cocktail Bars;Nightlife;Loun...            102
# 1000         Sandwiches;Salad;Italian;Pizza;Restaurants            103
# 460          Restaurants;Cafes;Bakeries;Food;Sandwiches            105
# 759                                 Restaurants;Italian            116
# 231   New Mexican Cuisine;Mexican;Restaurants;Southe...            120
# 674   Casinos;Hotels;Resorts;Arts & Entertainment;Ev...            126
# 18                             Hotels & Travel;Airports            127
# 280       Restaurants;Breakfast & Brunch;American (New)            129
# 56    Restaurants;Arts & Entertainment;Hotels;Event ...            133
#
#       Unnamed: 2 Unnamed: 3 Unnamed: 4
# 92           NaN        NaN        NaN
# 158          NaN        NaN        NaN
# 762          NaN        NaN        NaN
# 1017         NaN        NaN        NaN
# 524          NaN        NaN        NaN
# 393          NaN        NaN        NaN
# 333          NaN        NaN        NaN
# 361          NaN        NaN        NaN
# 298          NaN        NaN        NaN
# 987          NaN        NaN        NaN
# 519          NaN        NaN        NaN
# 1004         NaN        NaN        NaN
# 395          NaN        NaN        NaN
# 805          NaN        NaN        NaN
# 655          NaN        NaN        NaN
# 296          NaN        NaN        NaN
# 293          NaN        NaN        NaN
# 332          NaN        NaN        NaN
# 9            NaN        NaN        NaN
# 325          NaN        NaN        NaN
# 533          NaN        NaN        NaN
# 436          NaN        NaN        NaN
# 501          NaN        NaN        NaN
# 898          NaN        NaN        NaN
# 55           NaN        NaN        NaN
# 950          NaN        NaN        NaN
# 874          NaN        NaN        NaN
# 1011         NaN        NaN        NaN
# 814          NaN        NaN        NaN
# 725          NaN        NaN        NaN
# ...          ...        ...        ...
# 973          NaN        NaN        NaN
# 510          NaN        NaN        NaN
# 130          NaN        NaN        NaN
# 339          NaN        NaN        NaN
# 32           NaN        NaN        NaN
# 300          NaN        NaN        NaN
# 504          NaN        NaN        NaN
# 609          NaN        NaN        NaN
# 1036         NaN        NaN        NaN
# 99           NaN        NaN        NaN
# 782          NaN        NaN        NaN
# 657          NaN        NaN        NaN
# 819          NaN        NaN        NaN
# 750          NaN        NaN        NaN
# 206          NaN        NaN        NaN
# 388          NaN        NaN        NaN
# 917          NaN        NaN        NaN
# 1052         NaN        NaN        NaN
# 551          NaN        NaN        NaN
# 36           NaN        NaN        NaN
# 896          NaN        NaN
# 959          NaN        NaN        NaN
# 1000         NaN        NaN        NaN
# 460          NaN        NaN        NaN
# 759          NaN        NaN        NaN
# 231          NaN        NaN        NaN
# 674          NaN        NaN        NaN
# 18           NaN        NaN        NaN
# 280          NaN        NaN        NaN
# 56           NaN                   NaN
#
# [1099 rows x 17 columns]

# %%
#Filter all restaurants by is_bougie true
is_bougie = yelp_reviewd[yelp_reviewd["is_bougie"] == True]
text_data_seriesb = is_bougie["text"]
text_data_seriesb.head(10)
# Out:
# 0     Super simple place but amazing nonetheless. It...
# 1     *The shop was featured on Mind of a Chef with ...
# 2     Small unassuming place that changes their menu...
# 3     Lester's is located in a beautiful neighborhoo...
# 5     Wow, just the most tasty burguer I've ever had...
# 7     Cycle Pub Las Vegas was a blast! Got a groupon...
# 16    its delicious. its loud. its funny. seems like...
# 17    Love this place! If I ever have international ...
# 19    This place is awesome! Definitely authentic!!!...
# 28    Best burger place I've had in Toronto. Hands d...
# Name: text, dtype: object

# %%
RE_stopwords = r'\b(?:{})\b'.format('|'.join(stopwords))
# replace '|'-->' ' and drop all stopwords
wordsb = (text_data_seriesb
           .str.lower()
           .replace([r'\(','\)','\|','\,','\.','\?','\!','\_','\-','\:','\"','\*',"\'", RE_stopwords], ['','','','','','','',' ','','','','','', ''], regex=True)
           .str.cat(sep=' ')
           .split()
)

# generate DF out of Counter
rsltb = pd.DataFrame(Counter(wordsb).most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
print(rsltb)

# plot
#rslt.plot.bar(rot=0, figsize=(16,10), width=0.8)
# Out:
#             Frequency
# Word
# great            1834
# place            1758
# food             1462
# good             1333
# one              1135
# time             1120
# like             1088
# get              1028
# service           987
# love              960
# back              928
# go                901
# also              890
# really            866
# always            798
# well              784
# best              783
# ive               726
# would             707
# delicious         692
# nice              692
# friendly          683
# im                654
# us                632
# amazing           626
# staff             618
# dont              608
# even              576
# first             542
# try               542
# ...               ...
# courted             1
# destined            1
# flings              1
# sensuality          1
# begs                1
# towners             1
# suspicious          1
# bendie              1
# minded              1
# gratuity            1
# 10pm12am            1
# joked               1
# stalks              1
# stacks              1
# digiorno            1
# arteries            1
# protesting          1
# spinatos            1
# spunky              1
# cue                 1
# flap                1
# disarray            1
# tangled             1
# conspiring          1
# elope               1
# giggle              1
# lenses              1
# grope               1
# molelike            1
# critter             1
#
# [10000 rows x 1 columns]

# %%
#Repeat steps 5-8 with non-matching restaurants
#Filter all restaurants by is_bougie true
is_not_bougie = yelp_reviewd[yelp_reviewd["is_bougie"] == False]
text_data_seriesp = is_not_bougie["text"]
text_data_seriesp.head(10)
# Out:
# 4     Love coming here. Yes the place always needs t...
# 6     Had their chocolate almond croissant and it wa...
# 8     Who would have guess that you would be able to...
# 9     Always drove past this coffee house and wonder...
# 10    Not bad!! Love that there is a gluten-free, ve...
# 11    I'm not on the Poutini's train. It's fine but ...
# 12    This is currently my parents new favourite res...
# 13    Server was a little rude.\n\nOrdered the calam...
# 14    I thought Tidy's Flowers had a great reputatio...
# 15    Wanted to check out this place due to all the ...
# Name: text, dtype: object

# %%
RE_stopwords = r'\b(?:{})\b'.format('|'.join(stopwords))
# replace '|'-->' ' and drop all stopwords
wordsp = (text_data_seriesp
           .str.lower()
           .replace([r'\(','\)','\|','\,','\.','\?','\!','\_','\-','\:','\"','\*',"\'", RE_stopwords], ['','','','','','','',' ','','','','','', ''], regex=True)
           .str.cat(sep=' ')
           .split()
)

# generate DF out of Counter
rsltp = pd.DataFrame(Counter(wordsp).most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
print(rsltp)

# plot
#rslt.plot.bar(rot=0, figsize=(16,10), width=0.8)
# Out:
#              Frequency
# Word
# good              4275
# food              3808
# place             3637
# like              3261
# one               2709
# get               2505
# great             2413
# time              2365
# would             2360
# really            2282
# service           2200
# back              2031
# go                1887
# also              1883
# dont              1661
# im                1606
# nice              1598
# ordered           1508
# little            1480
# didnt             1455
# well              1434
# us                1375
# got               1324
# even              1316
# order             1298
# pretty            1293
# came              1262
# try               1225
# menu              1220
# ive               1205
# ...                ...
# screamed             3
# coquito              3
# place;               3
# billiards            3
# cappuccinos          3
# jeez                 3
# davids               3
# soirées              3
# jouer                3
# restuarant           3
# 130                  3
# shines               3
# causal               3
# whoops               3
# tentacles            3
# shio                 3
# pestle               3
# plateau              3
# yuca                 3
# sings                3
# sandwichs            3
# articles             3
# expansive            3
# reccomend            3
# mac&cheese           3
# cacao                3
# reminding            3
# guilt                3
# hakka                3
# familys              3
#
# [10000 rows x 1 columns]

# %%
odd_word = list({s for s in wordsb if s not in wordsp})
print(odd_word)
# Out:
# ['11\\/10', 'lifetimes', 'cass', 'qf', 'float\\/massage', 'nsync', 'mustvei', 'informative\\/thorough', 'stephan', 'chemicals', 'onand', 'friendgo', 'frieling', 'hades', 'renewal', 'missoula', 'y1', 'eton', 'achatter', 'danishes', 'pinnies', 'fallswith', 'cabarets', '$2$7', 'leftoversor', 'phenix', 'isabelle', 'thoughtful', '$2599', 'monies', 'purist', 'fulltime', 'goodhad', 'rescues', 'hiro', 'threaded', 'vaca', 'menuwhy', 'pistachioswonderful', '200%', 'saddened', 'feasts', 'zales', 
caribe', 'cleansed', 'ocopa', 'matronly', 'email\\/text', 'elvira', 'problèmes', 'theni', 'peripherals', 'mthtm', 'bombtoute', 'rums', '2200', 'connaissant', 'cutest', 'fitnessgetting', 'emina', 'peelyourown', 'bridesmaids', 'elope', 'ratingso', 'fillingno', 'steven', 'myosymmetrix', 'special\\/small', 'faque', 'slang', 'zeitounis', 'usingso', 'sacredness', 'macaroonstried', 'shoveling', 'gimlet', 'ladylike', 'induced', 'noncondescending', 'battering', 'pedestal', 'bramble', 'camden', 'appeasing', 'cornflower', 'admirably', 'knowledable', 'standout', 'attacker', 'reso', 'okwe', 'http\\/\\/wwwbirdandhikecom\\/hike\\/', 'plucked', 'mmmmmmm', 'semidry', 'perinatal', 'petersons', 'cleopatra', 'midwifery', 'botero', 'chores', 'rump', 'leland', 'wowza', 'hospitals', 'atom', 'tix4tonight', 'fraîcheur', 'trunks', 'girlish', 'springboard', 'fixation', 'descendants', 'bryans', 'easier;', 'gangsters', 'fi ...

# %%
odd_wordres = pd.DataFrame(Counter(odd_word).most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')
print(odd_wordres)
# Out:
#                        Frequency
# Word
# 11\/10                         1
# lifetimes                      1
# cass                           1
# qf                             1
# float\/massage                 1
# nsync                          1
# mustvei                        1
# informative\/thorough          1
# stephan                        1
# chemicals                      1
# onand                          1
# friendgo                       1
# frieling                       1
# hades                          1
# renewal                        1
# missoula                       1
# y1                             1
# eton                           1
# achatter                       1
# danishes                       1
# pinnies                        1
# fallswith                      1
# cabarets                       1
# $2$7                           1
# leftoversor                    1
# phenix                         1
# isabelle                       1
# thoughtful                     1
# $2599                          1
# monies                         1
# ...                          ...
# kaji                           1
# preoffice                      1
# tartares                       1
# choreographed                  1
# stemmed                        1
# vacherin                       1
# playfully                      1
# toters                         1
# painkiller                     1
# divinely                       1
# skinnyfats                     1
# becausethey                    1
# speciallymade                  1
# reuss                          1
# zapping                        1
# delicioius                     1
# snagandsave                    1
# ducknot                        1
# unfffff                        1
# mediterranea                   1
# apple\/fig                     1
# modern\/mark                   1
# receives                       1
# twinkle                        1
# bucks\/                        1
# vault                          1
# empathized                     1
# tonite                         1
# befriend                       1
# payback                        1
#
# [6603 rows x 1 columns]

# %%
# initilize by 0
# dictionary - business_id + counter
# increase counter for coorisponding business_id if you find a bougie word
# sort dictionary by values
# match review ID and resturant
business_id_to_counter = {}
for index, row in yelp_reviewd.iterrows():
    for word, word_row in odd_wordres.iterrows():
        if word in row["text"]:
            business_id = row["business_id"]
            # is the business in the dictionary already?
            if business_id in business_id_to_counter:
                business_id_to_counter[business_id and ] += 1
            else:
                # add the business
                business_id_to_counter[business_id] = 1

print(f"business_id_to_counter={business_id_to_counter}")
#sort the dictionary by values
sorted_biz = sorted(business_id_to_counter.items(), key=lambda kv: kv[1])
print(f"sorted_biz={sorted_biz}")
# Out:
1), ('FhgAHo-8--equM8w5UZ41Q', 1), ('p-sAj41iE2EtZZ-SmYVdGQ', 1), ('kmIQmtKMmFrLRDisg9ftLg', 1), ('cDvnaqZ3T35mDCvHqyWlJg', 1), ('aP2ZadiZMZvIXyikcNfQPA', 1), ('VcGyezSNtkNBr2HidcaM1A', 1), ('GPda46cZ8YRFw36QsNwDgg', 1), ('HccqNuvwDCrnAAM5e5lQ_w', 1), ('UpW3jyJ3_kTG7oDSflwnMA', 1), ('vcxvQyAggPqxcHwvJXvjGg', 2), ('qR62k9TVEVwRuQH6-4avHA', 2), ('vtJKOOyg0NisrB45K33cdQ', 2), ('1Lbq92b6B9z1FYk5mS2R9Q', 2), ('M5dqqrla2JsBn5G3pV3Dmg', 2), ('cZBCVzd4lg_jx8IiFz-Iag', 2), ('K8MWIwCrS5w-Dbi9UHOlhw', 2), ('48OQw36mJ_xhOvR7duH1kg', 2), ('XgsIf7s2zM-cC29WUD-NZQ', 2), ('WyZAeMGsjUE7OToI4Jdqfw', 2), ('WFB1fn8rWNukmmIfTg6AMw', 2), ('r_oCBNif2W8mnSXnrXMwPQ', 2), ('s6L6SdVYhPcOQEDmNIg1-g', 2), ('5Hm7p_B03gc_hIKvjriqLw', 2), ('QIn3PuGUkinSibUn-NsljQ', 2), ('936MHN9AylEe6xTKQd5b-Q', 2), ('gvMBaZZm0BhvSyZPN77RPA', 2), ('RtXj1StQUbCMEmxRR10Bqg', 2), ('3JekfARgFuMeLTMcOpgqyQ', 2), ('jUqCRsuGqwePkDKQ1fM6TA', 2), ('63dCBZQILHR-QogyKXnvXw', 2), ('CLbaNtbKC2xGqgMP9vR3jw', 2), ('ZnUBkQrpRQDk_Y0hPtlgNw', 2), ('3vxIqhm2jCVjkUWtmDvTsw', 2), ('xlNOEaT6XQvKN7tIZvOqqA', 2), ('mnU3iGsL55MCWXiWV3AcAQ', 2), ('BfIcrMq0Me0D7BBSYij7Fg', 2), ('hPfszfTC6xu9Ysd3sIHm8Q', 2), ('7k7pBjR-Z12DTjfBZF ...

# %%
#With the New Bugie Businesses
bougie_biz = pd.merge(bougie_businesses, yelp_business_data, on='business_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-b415f248a237> in <module>
#       1 #With the New Bugie Businesses
# ----> 2 bougie_biz = pd.merge(bougie_businesses, yelp_business_data, on='business_id')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     549         (self.left_join_keys,
#     550          self.right_join_keys,
# --> 551          self.join_names) = self._get_merge_keys()
#     552
#     553         # validate the merge keys dtypes. We may need to coerce
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     869                     if lk is not None:
#     870                         left_keys.append(left._get_label_or_level_values(
# --> 871                             lk, stacklevel=stacklevel))
#     872                         join_names.append(lk)
#     873                     else:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis, stacklevel)
#    1380             values = self.axes[axis].get_level_values(key)._values
#    1381         else:
# -> 1382             raise KeyError(key)
#    1383
#    1384         # Check for duplicates
#
# KeyError: 'business_id'
